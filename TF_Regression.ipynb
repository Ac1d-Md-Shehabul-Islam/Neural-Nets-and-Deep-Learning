# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eeebb9ff-5802-4d41-a136-b37a3903aff4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eeebb9ff-5802-4d41-a136-b37a3903aff4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_data.csv to house_data.csv

# %%
df = pd.read_csv('house_data.csv')
df.head(4)
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
#
# [4 rows x 21 columns]

# %%
# df.isnull().sum()

# %%
df = df.fillna(df.mean()) # to fill null values with mean

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21613.0  4.580302e+09  ...  7.308900e+09  9.900000e+09
# price          21613.0  5.400881e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21613.0  3.370842e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21613.0  2.114757e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21613.0  2.079900e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21613.0  1.510697e+04  ...  1.068800e+04  1.651359e+06
# floors         21613.0  1.494309e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21613.0  7.541757e-03  ...  0.000000e+00  1.000000e+00
# view           21613.0  2.343034e-01  ...  0.000000e+00  4.000000e+00
# condition      21613.0  3.409430e+00  ...  4.000000e+00  5.000000e+00
# grade          21613.0  7.656873e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21613.0  1.788396e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
plt.figure(figsize=(10,6))
sns.displot(df['price'])

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()['price'].sort_values() # sqft_living is highly correlated with price
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605565
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price', y='sqft_living',data=df)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms', y='price',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='crest')

# %%
df.sort_values('price',ascending=False).head(10)
# Out:
#               id             date  ...  sqft_living15  sqft_lot15
# 7252  6762700020  20141013T000000  ...           3940        8800
# 3914  9808700762  20140611T000000  ...           3930       25449
# 9254  9208900037  20140919T000000  ...           4540       42730
# 4411  2470100110  20140804T000000  ...           3560       24345
# 1448  8907500070  20150413T000000  ...           4600       21750
# 1315  7558700030  20150413T000000  ...           4320       24619
# 1164  1247600105  20141020T000000  ...           3430       26788
# 8092  1924059029  20140617T000000  ...           3270       10454
# 2626  7738500731  20140815T000000  ...           3030       23408
# 8638  3835500195  20140618T000000  ...           3720       14592
#
# [10 rows x 21 columns]

# %%
len(df)*0.01
# Out:
# 216.13

# %%
bottom_99_perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=bottom_99_perc,edgecolor=None,alpha=0.2,hue='price',palette='RdYlGn')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df = df.drop('id',axis=1)
df.head()
# Out:
#               date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0  20141013T000000  221900.0         3  ... -122.257           1340        5650
# 1  20141209T000000  538000.0         3  ... -122.319           1690        7639
# 2  20150225T000000  180000.0         2  ... -122.233           2720        8062
# 3  20141209T000000  604000.0         4  ... -122.393           1360        5000
# 4  20150218T000000  510000.0         3  ... -122.045           1800        7503
#
# [5 rows x 20 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# def year_extract(date):
#   return date.year

# %%
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year  month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)

# %%
 df.groupby('month').mean()['price'].plot()

# %%
 df.groupby('year').mean()['price'].plot()

# %%
# df = df.drop('date',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
X_train.shape # 19 incoming features
# Out:
# (15129, 19)

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train, y=y_train, 
          validation_data=(X_test,y_test),
          batch_size=128,
          epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 4ms/step - loss: 426307254681.6000 - val_loss: 433014833152.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 424691562905.6000 - val_loss: 429538050048.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 418242803302.4000 - val_loss: 395135844352.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 354763321344.0000 - val_loss: 271903719424.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 231133017156.2667 - val_loss: 129032241152.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 120080729770.6667 - val_loss: 104562835456.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 97846915959.4667 - val_loss: 102788071424.0000
# Epoch 8/400
# ...

# %%
pd.DataFrame(model.history.history) # check overfitting
# Out:
#              loss      val_loss
# 0    4.236267e+11  4.330148e+11
# 1    4.226645e+11  4.295381e+11
# 2    4.082882e+11  3.951358e+11
# 3    3.341217e+11  2.719037e+11
# 4    1.864082e+11  1.290322e+11
# ..            ...           ...
# 395  2.816593e+10  2.823653e+10
# 396  2.818070e+10  2.800217e+10
# 397  2.814508e+10  2.802454e+10
# 398  2.820391e+10  2.799278e+10
# 399  2.812607e+10  2.805571e+10
#
# [400 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
loss = pd.DataFrame(model.history.history)
loss.plot()  # perfect behaviour we wanted to see / no overfitting

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 28055713423.78923

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 167498.39827230954

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 104083.34268728794

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.400881e+05 # mean absolute error is good
# Out:
# 540088.1

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8002197436193585

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')
